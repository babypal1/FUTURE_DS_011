# %% [markdown]
# <a href="https://colab.research.google.com/github/babypal1/FUTURE_DS_011/blob/main/class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install jovian -- upgrade --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# %pip install jovian --upgrade --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 3.1 MB/s eta 0:00:00
# ...

# %%
# !pip install jovian --upgrade --quiet

# %%
# !pip install jovian --quiet

# %%
import jovian

# %%
jovian.commit = ('first-step-with-python-demo')

# %%
jovian.commit
# Out:
# 'first-step-with-python-demo'
